# %% [markdown]
# <a href="https://colab.research.google.com/github/varundhondi/python/blob/main/07/09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
df1=pd.DataFrame([[1,2],[3,4]],columns=['a','b'])
df2=pd.DataFrame([[5,6],[7,8]],columns=['a','b'])
df1=df1.append(df2)
print(df1)
print("after deleting")
df1=df1.drop(0)
print(df1)
# Out:
#    a  b
# 0  1  2
# 1  3  4
# 0  5  6
# 1  7  8
# after deleting
#    a  b
# 1  3  4
# 1  7  8
# <ipython-input-4-0e6cac41ec6e>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1=df1.append(df2)

# %%
df=pd.DataFrame()
df['Name']=['Ankit','Ankita','Yashv','vikal']
df['CAT1_marks']=[23,24,25,21]
df['CAT2_marks']=[23,24,21,20]
df['FAT_marks']=[45,43,42,46]
print(df)
df.loc[len(df.index)]=['pavan',23,23,41]
print(df)
df['total']=df['CAT1_marks']+df['CAT2_marks']+df['FAT_marks']
df
df.sort_values('total')
# Out:
#      Name  CAT1_marks  CAT2_marks  FAT_marks
# 0   Ankit          23          23         45
# 1  Ankita          24          24         43
# 2   Yashv          25          21         42
# 3   vikal          21          20         46
#      Name  CAT1_marks  CAT2_marks  FAT_marks
# 0   Ankit          23          23         45
# 1  Ankita          24          24         43
# 2   Yashv          25          21         42
# 3   vikal          21          20         46
# 4   pavan          23          23         41
#      Name  CAT1_marks  CAT2_marks  FAT_marks  total
# 3   vikal          21          20         46     87
# 4   pavan          23          23         41     87
# 2   Yashv          25          21         42     88
# 0   Ankit          23          23         45     91
# 1  Ankita          24          24         43     91

# %%
filename='/weather.csv'
df=pd.read_csv(filename)
print(df)
# Out:
#    month  avg_low  avg_high  record_high  record_low  avg_preci
# 0    Jan       58        42           74          22       2.95
# 1    Feb       61        45           78          26       3.02
# 2    Mar       65        48           84          25       2.34
# 3    Apr       67        50           92          28       1.02
# 4    May       71        53           98          35       0.48
# 5    Jun       75        56          107          41       0.11
# 6    Jul       77        58          105          44       0.00
# 7    Aug       77        59          102          43       0.03
# 8    Sep       77        57          103          40       0.17
# 9    Oct       73        54           96          34       0.81
# 10   Nov       64        48           84          30       1.70
# 11   Dec       58        42           73          21       2.56
